# %% [markdown]
# ## One network, many uses
#
# This notebook follows the tutorial: [One neural network, many uses: image captioning, image search, similar images and similar words using one model](https://towardsdatascience.com/one-neural-network-many-uses-build-image-search-image-captioning-similar-words-and-similar-1e22080ce73d)
#
# Made by [@paraschopra](https://twitter.com/paraschopra)
#
# MIT License.

# %% [markdown]
# ### IMPORTANT: Dataset NOT included (please download separately)
#
# To follow along, you'll need to download the Flickr8K dataset. Fill [this form](https://forms.illinois.edu/sec/1713398) and you'll receive a download link on your email. (There's also a [direct link to download the 1GB Flickr8K dataset](https://github.com/jbrownlee/Datasets/releases/download/Flickr8k/Flickr8k_Dataset.zip) Extract the zip file in the 'Flicker8k_Dataset' folder in the same directory as your notebook. You'll also need to download captions [from here](http://cs.stanford.edu/people/karpathy/deepimagesent/caption_datasets.zip). Extract captions in the folder 'caption_datasets'.

# %%
import matplotlib.pyplot as plt
import random
import json
import ipympl
import string

# %%
# %matplotlib widget

# %%
from scipy import ndimage
import numpy as np
from copy import deepcopy
from PIL import Image
import IPython.display
from math import floor

# %%
import torch
import torch.nn as nn                     # neural networks
import torch.nn.functional as F           # layers, activations and more
import torch.optim as optim  
import torchvision.transforms.functional as TF

# %%
import torchvision
from torchvision import datasets, models, transforms

# %%
is_cuda = torch.cuda.is_available()
is_cuda
# Out:
# True

# %%
if(is_cuda):
    USE_GPU = True
else:
    USE_GPU = False

# %%
ENDWORD = '<END>'
STARTWORD = '<START>'
PADWORD = '<PAD>'
HEIGHT = 299
WIDTH = 299
INPUT_EMBEDDING = 300
HIDDEN_SIZE = 300
OUTPUT_EMBEDDING = 300

CAPTION_FILE = 'caption_datasets/dataset_flickr8k.json'
IMAGE_DIR = 'Flicker8k_Dataset/'

# %%
inception = models.inception_v3(pretrained=True)

# %%
#Here we examine the final fully connected layer and see 1000 outputs
inception.fc
# Out:
# Linear(in_features=2048, out_features=1000, bias=True)

# %%
def set_parameter_requires_grad(model, feature_extracting):
    if feature_extracting:
        for param in model.parameters():
            param.requires_grad = False

# %%
#Here we set parameters to not require gradient
set_parameter_requires_grad(inception, True)

#Number of features input to the fully connected layer
num_ftrs = inception.fc.in_features

#Change model to have output of dimension embedding in final fully connected layer
inception.fc = nn.Linear(num_ftrs, INPUT_EMBEDDING)

# %%
#Here we confirm that we set the number of outputs to match the outputs of the embedding
inception.fc
# Out:
# Linear(in_features=2048, out_features=300, bias=True)

# %%
inception.load_state_dict(torch.load('models/inception_epochs_40.pth'))

# %%
if(USE_GPU):
    inception.cuda()

# %% [markdown]
# ## Let's Examine the JSON File to Determine How Data is Stored and Handled by Helper Class

# %%
all_data = json.load(open('caption_datasets/dataset_flickr8k.json', 'r'))

# %%
myDataList = [data for data in all_data['images']]

# %%
myDataList[0]
# Out:
# {'sentids': [0, 1, 2, 3, 4],
#  'imgid': 0,
#  'sentences': [{'tokens': ['a',
#     'black',
#     'dog',
#     'is',
#     'running',
#     'after',
#     'a',
#     'white',
#     'dog',
#     'in',
#     'the',
#     'snow'],
#    'raw': 'A black dog is running after a white dog in the snow .',
#    'imgid': 0,
#    'sentid': 0},
#   {'tokens': ['black', 'dog', 'chasing', 'brown', 'dog', 'through', 'snow'],
#    'raw': 'Black dog chasing brown dog through snow',
#    'imgid': 0,
#    'sentid': 1},
#   {'tokens': ['two',
#     'dogs',
#     'chase',
#     'each',
#     'other',
#     'across',
#     'the',
#     'snowy',
#     'ground'],
#    'raw': 'Two dogs chase each other across the snowy ground .',
#    'imgid': 0,
#    'sentid': 2},
#   {'tokens': ['two', 'dogs', 'play', 'together', 'in', 'the', 'snow'],
#    'raw': 'Two dogs play together in the snow .',
#    'imgid': 0,
#    'sentid': 3},
#   {'tokens': ['two',
#     'dogs',
#     'running',
#     'through',
#     'a',
#     'low',
#     'lying',
#     'body',
#     'of',
#     'water'],
#    'raw': 'Two dogs running through a low lying body of water .',
#    'imgid': 0,
#    'sentid': 4}],
#  'split': 'train',
#  'filename': '2513260012_03d33305cf.jpg'}

# %% [markdown]
# ## Class for holding data

# %%
class Flickr8KImageCaptionDataset:
    
    def __init__(self):
        
        all_data = json.load(open('caption_datasets/dataset_flickr8k.json', 'r'))
        all_data=all_data['images']
        
        self.training_data = []
        self.test_data = []
        self.w2i = {ENDWORD: 0, STARTWORD: 1}
        self.word_frequency = {ENDWORD: 0, STARTWORD: 0}
        self.i2w = {0: ENDWORD, 1: STARTWORD}
        self.tokens = 2 #END is default
        self.batch_index = 0
        
        #Define the device within the data loader object
        if(USE_GPU):
            self.device = torch.device('cuda')
        else:
            self.device = torch.device('cpu')
        
        for data in all_data:
            if(data['split']=='train'):
                self.training_data.append(data)
            else:
                self.test_data.append(data)
                
            for sentence in data['sentences']:
                for token in sentence['tokens']:
                    if(token not in self.w2i.keys()):
                        self.w2i[token] = self.tokens
                        self.i2w[self.tokens] = token
                        self.tokens +=1
                        self.word_frequency[token] = 1
                    else:
                        self.word_frequency[token] += 1
                        
    def image_to_tensor(self,filename):
        image = Image.open(filename)
        image = TF.resize(img=image, size=(HEIGHT,WIDTH))
       
        image = TF.to_tensor(pic=image)
        image = TF.normalize(image, mean=[0.485, 0.456, 0.406],
                                     std=[0.229, 0.224, 0.225])
        
        return torch.unsqueeze(image,0)

    
    def return_train_batch(self, bs=1): #size of 1 always
        for index in range(len(self.training_data)):
            sentence_index = np.random.randint(len(self.training_data[index]['sentences']))
            output_sentence_tokens = deepcopy(self.training_data[index]['sentences'][sentence_index]['tokens'])
            output_sentence_tokens.append(ENDWORD) #corresponds to end word

            image = self.image_to_tensor('Flicker8k_Dataset/'+self.training_data[index]['filename'])

            yield image, list(map(lambda x: self.w2i[x], output_sentence_tokens)), output_sentence_tokens, index
    
    def convert_tensor_to_word(self, output_tensor):
        output = F.log_softmax(output_tensor.detach().squeeze(), dim=0).to('cpu').numpy()
        return self.i2w[np.argmax(output)]
    
    def convert_sentence_to_tokens(self, sentence):
        tokens = sentence.split(" ")
        converted_tokens= list(map(lambda x: self.w2i[x], tokens))
        converted_tokens.append(self.w2i[ENDWORD])
        return converted_tokens
    
    def caption_image_greedy(self, net, image_filename, max_words=15): #non beam search, no temperature implemented
       
        net.eval()
        inception.eval()
        image_tensor = self.image_to_tensor(image_filename).to(self.device)
        hidden=None
        embedding=None
        words = []
    
        input_token = STARTWORD
        input_tensor = torch.tensor(self.w2i[input_token]).type(torch.LongTensor).to(self.device)
        
        for i in range(max_words):   
            if(i==0):
                out, hidden=net(input_tensor, hidden=image_tensor, process_image=True)
            else:
                out, hidden=net(input_tensor, hidden)
                
            word = self.convert_tensor_to_word(out)
            
            input_token = self.w2i[word]
            input_tensor = torch.tensor(input_token).type(torch.LongTensor).to(self.device)
            
            if(word==ENDWORD):
                break
            else:
                words.append(word)

        return ' '.join(words)
    
    
    def forward_beam(self, net, hidden, process_image, partial_sentences, sentences, topn_words=5, max_sentences=10):
        max_words = 50
        hidden_index = {}
        while(sentences<max_sentences):
            #print("Sentences: ",sentences)
            new_partial_sentences = []
            new_partial_sentences_logp = []
            new_partial_avg_logp= []
            
            if(len(partial_sentences[-1][0])>max_words):
                break
            
            for partial_sentence in partial_sentences:
                input_token = partial_sentence[0][-1]
                input_tensor = torch.tensor(self.w2i[input_token]).type(torch.FloatTensor).to(self.device)
                if(partial_sentence[0][-1]==STARTWORD):
                    out, hidden=net(input_tensor, hidden, process_image=True)
                else:
                    out, hidden=net(input_tensor, torch.tensor(hidden_index[input_token]).to(self.device))

                #take first topn words and add as children to root
                out = F.log_softmax(out.detach().squeeze(), dim=0).to('cpu').numpy()
                out_indexes = np.argsort(out)[::-1][:topn_words]
        
                for out_index in out_indexes:
                    if(self.i2w[out_index]==ENDWORD):
                        sentences=sentences+1
                    else:
                        total_logp = float(out[out_index]) + partial_sentence[1]
                        new_partial_sentences_logp.append(total_logp)
                        new_partial_sentences.append([np.concatenate((partial_sentence[0], [self.i2w[out_index]])),
                                                      total_logp])
                        
                        len_words = len(new_partial_sentences[-1][0])       
                        new_partial_avg_logp.append(total_logp/len_words)
                        #print(self.i2w[out_index])
                        hidden_index[self.i2w[out_index]] = deepcopy(hidden.detach().to('cpu').numpy())
            
            #select topn partial sentences
            top_indexes = np.argsort(new_partial_sentences_logp)[::-1][:topn_words]
            new_partial_sentences = np.array(new_partial_sentences)[top_indexes]
            #print("New partial sentences (topn):", new_partial_sentences)
            partial_sentences = new_partial_sentences
        return partial_sentences
    
    def caption_image_beam_search(self, net, image_filename, topn_words=10, max_sentences=10):
        net.eval()
        inception.eval()
        image_tensor = self.image_to_tensor(image_filename).to(self.device)
        hidden=None
        embedding=None
        words = []
    
        sentences = 0
        partial_sentences = [[[STARTWORD], 0.0]]
        #root_id = hash(input_token) #for start word
        #nodes = {}
        #nodes[root_id] = Node(root_id, [STARTWORD, 0], None)
       
        partial_sentences = self.forward_beam(net, image_tensor, True, partial_sentences, sentences,  topn_words, 
                                              max_sentences)
    
        logp = []
        joined_sentences = []
    
        for partial_sentence in partial_sentences:
            joined_sentences.append([' '.join(partial_sentence[0][1:]),partial_sentence[1]])
                  
        return joined_sentences

    def print_beam_caption(self, net, train_filename, num_captions=0):
        beam_sentences = f.caption_image_beam_search(net,train_filename)
        if(num_captions==0):
            num_captions=len(beam_sentences)
        for sentence in beam_sentences[:num_captions]:
            print(sentence[0]+" [",sentence[1], "]")

# %% [markdown]
# ## class for network

# %%
class IC_V6(nn.Module):
    
    #V2: Fed image vector directly as hidden and fed words generated as iputs back to LSTM
    #V3: Added an embedding layer between words input and GRU/LSTM
    
    def __init__(self, token_dict_size):
        super(IC_V6, self).__init__()
        
        #Input is an image of height 500, and width 500
        self.embedding_size = INPUT_EMBEDDING
        self.hidden_state_size = HIDDEN_SIZE
        self.token_dict_size = token_dict_size
        self.output_size = OUTPUT_EMBEDDING
        
        self.batchnorm = nn.BatchNorm1d(self.embedding_size)
        
        self.input_embedding = nn.Embedding(self.token_dict_size, self.embedding_size)
        
        self.embedding_dropout = nn.Dropout(p=0.22)
        self.gru_layers = 3
        
        self.gru = nn.GRU(input_size=self.embedding_size, hidden_size=self.hidden_state_size, 
                          num_layers=self.gru_layers, dropout=0.22)
        self.linear = nn.Linear(self.hidden_state_size, self.output_size)
        self.out = nn.Linear(self.output_size, token_dict_size)
        
    def forward(self, input_tokens, hidden, process_image=False, use_inception=True):
        if(USE_GPU):
            device = torch.device('cuda')
        else:
            device = torch.device('cpu')
        
        if(process_image):
            if(use_inception):
                inp=self.embedding_dropout(inception(hidden))
            else:
                inp=hidden
            #inp=self.batchnorm(inp)
            hidden=torch.zeros((self.gru_layers,1, self.hidden_state_size)).to(device)
        else:
            inp=self.embedding_dropout(self.input_embedding(input_tokens.view(1).type(torch.LongTensor).to(device)))
            #inp=self.batchnorm(inp)
            
        hidden = hidden.view(self.gru_layers,1,-1)
        inp = inp.view(1,1,-1)
        
        out, hidden = self.gru(inp, hidden)
        out = self.out(self.linear(out))
        
        return out, hidden

# %%
f = Flickr8KImageCaptionDataset()

# %% [markdown]
# #### Let's Take a look at the Training Data to See How it is Passed to the Model

# %%
my_train_data = list(f.return_train_batch())

# %%
my_train_data[100]
# Out:
# (tensor([[[[-0.8678, -1.1075, -1.5357,  ...,  0.1254, -0.1143, -1.4843],
#            [-0.8507, -1.2617, -1.5185,  ...,  0.1254, -0.0801, -1.1418],
#            [-0.9192, -1.2959, -1.4500,  ...,  0.1768,  0.0398, -0.7479],
#            ...,
#            [-1.2617, -1.2103, -0.8849,  ..., -0.4054,  0.0056, -0.3712],
#            [-1.1418, -1.2103, -0.8849,  ..., -0.2684,  0.2967, -0.2171],
#            [-1.0219, -1.1075, -1.1589,  ..., -0.2684, -0.0801,  0.1768]],
#
#           [[-0.7227, -0.9503, -1.3529,  ...,  0.4853,  0.0651, -1.3704],
#            [-0.6877, -1.1253, -1.3880,  ...,  0.5028,  0.0476, -1.1429],
#            [-0.7402, -1.1779, -1.3529,  ...,  0.4503,  0.1001, -0.6877],
#            ...,
#            [-1.1604, -1.0378, -0.6702,  ..., -0.0924,  0.4503, -0.0749],
#            [-1.0903, -1.0903, -0.6176,  ..., -0.0224,  0.7829, -0.0924],
#            [-0.8978, -1.0553, -1.0028,  ...,  0.0301,  0.4328,  0.3452]],
#
#           [[-0.4450, -0.5844, -0.9504,  ...,  0.8274,  0.3568, -0.9504],
#            [-0.4450, -0.7936, -0.9156,  ...,  0.8448,  0.3568, -0.7238],
#            [-0.5844, -0.8284, -0.8633,  ...,  0.8797,  0.4788, -0.3055],
#            ...,
#            [-1.3513, -1.3164, -1.0027,  ..., -1.0027, -0.9330, -1.1596],
#            [-1.2641, -1.3339, -1.1073,  ..., -0.7587, -0.5670, -0.8807],
#            [-1.2990, -1.4036, -1.3861,  ..., -0.7238, -0.7064, -0.4101]]]]),
#  [10, 856, 230, 28, 2, 74, 857, 399, 0],
#  ['the', 'flat', 'side', 'of', 'a', 'large', 'rocky', 'mountain', '<END>'],
#  100)

# %%
f.tokens
# Out:
# 8385

# %%
f.word_frequency
# Out:
# {'<END>': 0,
#  '<START>': 0,
#  'a': 62433,
#  'black': 3830,
#  'dog': 8111,
#  'is': 9251,
#  'running': 2057,
#  'after': 182,
#  'white': 3921,
#  'in': 18811,
#  'the': 18248,
#  'snow': 1542,
#  'chasing': 183,
#  'brown': 2566,
#  'through': 2020,
#  'two': 5611,
#  'dogs': 2111,
#  'chase': 40,
#  'each': 421,
#  'other': 762,
#  'across': 471,
#  'snowy': 422,
#  'ground': 354,
#  'play': 738,
#  'together': 409,
#  'low': 66,
#  'lying': 97,
#  'body': 191,
#  'of': 6653,
#  'water': 2764,
#  'little': 1764,
#  'baby': 419,
#  'plays': 522,
#  'croquet': 5,
#  'girl': 3312,
#  'next': 745,
#  'to': 3135,
#  'truck': 82,
#  'child': 1540,
#  'playing': 1992,
#  'croquette': 1,
#  'by': 1233,
#  'kid': 183,
#  'front': 1372,
#  'car': 426,
#  'with': 7702,
#  'put': 25,
#  'and': 8796,
#  'ball': 1773,
#  'boy': 3575,
#  'hammer': 4,
#  'beside': 246,
#  'has': 554,
#  'something': 344,
#  'hot': 29,
#  'pink': 734,
#  'its': 910,
#  'mouth': 988,
#  'holding': 1314,
#  'hat': 677,
#  'shirt': 1953,
#  'carrying': 427,
#  'while': 1953,
#  'walking': 1164,
#  'looking': 741,
#  'forward': 25,
#  'along': 521,
#  'beach': 1046,
#  'wearing': 3049,
#  'collar': 197,
#  'walks': 546,
#  'on': 10675,
#  'sand': 465,
#  'near': 1020,
#  'large': 1227,
#  'ocean': 463,
#  'red': 2681,
#  'frisbee': 337,
#  'standing': 1777,
#  'sandy': 109,
#  'drops': 5,
#  'disc': 23,
#  'flying': 170,
#  'air': 1060,
#  'catching': 109,
#  'dropping': 12,
#  'cyclist': 72,
#  'helmet': 356,
#  'riding': 901,
#  'pavement': 48,
#  'bike': 865,
#  'street': 933,
#  'person': 1521,
#  'down': 1829,
#  'woman': 3392,
#  'wears': 114,
#  'blue': 2270,
#  'as': 855,
#  'she': 93,
#  'goes': 73,
#  'for': 937,
#  'ride': 254,
#  'shade': 17,
#  'road': 394,
#  'man': 7194,
#  'dressed': 561,
#  'purple': 309,
#  'bandanna': 40,
#  'smiles': 190,
#  'at': 2869,
#  'people': 2849,
#  'watching': 248,
#  'him': 398,
#  'leather': 67,
#  'chaps': 4,
#  'chainmail': 1,
#  'codpiece': 1,
#  'poses': 142,
#  'camera': 696,
#  'stands': 864,
#  'onlookers': 51,
#  'there': 303,
#  'men': 1098,
#  't': 165,
#  'woodland': 21,
#  'runs': 921,
#  'some': 616,
#  'trees': 260,
#  'young': 2615,
#  'dancing': 143,
#  'around': 643,
#  'short': 75,
#  'sleeved': 17,
#  'jeans': 224,
#  'stops': 13,
#  'smile': 104,
#  'dress': 347,
#  'back': 387,
#  'grenade': 1,
#  'smiling': 463,
#  'braids': 6,
#  'looks': 509,
#  'green': 1223,
#  'skier': 178,
#  'yellow': 1202,
#  'jacket': 675,
#  'airborne': 75,
#  'above': 224,
#  'mountains': 204,
#  'jumps': 979,
#  'high': 293,
#  'view': 84,
#  'skiing': 115,
#  'fluorescent': 1,
#  'very': 162,
#  'it': 396,
#  'though': 22,
#  'he': 204,
#  'somone': 1,
#  'doing': 431,
#  'ski': 103,
#  'jump': 405,
#  'pants': 259,
#  'appears': 36,
#  'almost': 22,
#  'fly': 38,
#  'into': 1068,
#  'sky': 144,
#  'photographer': 24,
#  'over': 1401,
#  'hills': 24,
#  'videotaping': 3,
#  'natural': 18,
#  'landscape': 45,
#  'out': 753,
#  'rolling': 51,
#  'tripod': 14,
#  'lady': 222,
#  'her': 1171,
#  'set': 107,
#  'up': 1279,
#  'field': 1277,
#  'record': 7,
#  'bunch': 56,
#  'girls': 843,
#  'cheerleader': 17,
#  'outfits': 64,
#  'group': 1195,
#  'cheerleaders': 22,
#  'parade': 67,
#  'perform': 34,
#  'many': 180,
#  'walk': 318,
#  'uniforms': 113,
#  'boat': 276,
#  'canopy': 6,
#  'floating': 36,
#  'calm': 10,
#  'waters': 27,
#  'roof': 15,
#  'middle': 162,
#  'solitude': 1,
#  'floats': 17,
#  'lake': 332,
#  'catches': 123,
#  'midair': 208,
#  'terrier': 31,
#  'mix': 3,
#  'leaping': 138,
#  'object': 155,
#  'old': 173,
#  'sitting': 1357,
#  'an': 2400,
#  'advertisement': 15,
#  'asian': 198,
#  'waiting': 117,
#  'underground': 4,
#  'train': 108,
#  'stop': 35,
#  'sits': 577,
#  'transit': 3,
#  'station': 34,
#  'backlit': 8,
#  'subway': 72,
#  'umbrella': 81,
#  'aquos': 1,
#  'commercial': 2,
#  'wall': 550,
#  'blond': 194,
#  'trail': 146,
#  'side': 301,
#  'metal': 115,
#  'fence': 339,
#  'coat': 269,
#  'rural': 45,
#  'flute': 12,
#  'parka': 12,
#  'fenced': 54,
#  'past': 146,
#  'enclosed': 13,
#  'area': 395,
#  'family': 86,
#  'nine': 3,
#  'including': 11,
#  'four': 499,
#  'children': 1151,
#  'pose': 215,
#  'brick': 172,
#  'fireplace': 11,
#  'mantle': 2,
#  'christmas': 38,
#  'tree': 420,
#  'posing': 284,
#  'happy': 20,
#  'couples': 8,
#  'kids': 336,
#  'picture': 418,
#  'sweater': 119,
#  'pointing': 63,
#  'one': 1211,
#  'arms': 245,
#  'outstretched': 38,
#  'finger': 36,
#  'pointed': 13,
#  'another': 951,
#  'stares': 19,
#  'from': 913,
#  'behind': 628,
#  'who': 215,
#  'his': 2334,
#  'look': 260,
#  'toward': 144,
#  'points': 58,
#  'index': 1,
#  'hallway': 18,
#  'warily': 1,
#  'investigating': 1,
#  'medium': 27,
#  'sized': 27,
#  'small': 1269,
#  'larger': 36,
#  'grassy': 471,
#  'big': 278,
#  'tall': 146,
#  'grass': 1612,
#  'three': 1369,
#  'flowers': 148,
#  'stuffed': 63,
#  'kitten': 8,
#  'garden': 54,
#  'among': 47,
#  'wildflowers': 4,
#  'palying': 2,
#  'toy': 580,
#  'cat': 64,
#  'long': 312,
#  'raises': 36,
#  'eyebrow': 2,
#  'stripes': 16,
#  'handicap': 2,
#  'signs': 49,
#  'african': 54,
#  'american': 97,
#  'building': 506,
#  'handicapped': 3,
#  'space': 15,
#  'orange': 743,
#  'backwards': 34,
#  'wet': 179,
#  'stick': 467,
#  'shore': 170,
#  'bounds': 17,
#  'splashing': 128,
#  'off': 761,
#  'paws': 30,
#  'carries': 128,
#  'are': 3466,
#  'racing': 226,
#  'ractrack': 1,
#  'race': 380,
#  'track': 289,
#  'greyhounds': 42,
#  'muzzles': 23,
#  'inside': 173,
#  'curb': 24,
#  'railed': 3,
#  'dirt': 588,
#  'run': 366,
#  'baseball': 288,
#  'pitcher': 15,
#  'shelton': 1,
#  'throws': 66,
#  'player': 727,
#  'glove': 17,
#  'pitches': 4,
#  'male': 114,
#  'sports': 69,
#  'outfit': 157,
#  'tries': 106,
#  'catch': 366,
#  'wades': 12,
#  'rock': 755,
#  'waded': 1,
#  'shallow': 128,
#  'reach': 27,
#  'outcropping': 7,
#  'light': 167,
#  'paw': 13,
#  'about': 149,
#  'ready': 123,
#  'exit': 2,
#  'swim': 95,
#  '5': 19,
#  'school': 46,
#  'cross': 74,
#  'takes': 170,
#  'outside': 787,
#  'photograph': 38,
#  'taking': 204,
#  'pictures': 67,
#  'women': 650,
#  'stand': 515,
#  'jean': 26,
#  'hand': 348,
#  'chest': 28,
#  'bruised': 1,
#  'nose': 88,
#  'writing': 32,
#  'hands': 243,
#  'video': 40,
#  'rental': 1,
#  'store': 111,
#  'denim': 35,
#  'bookcase': 1,
#  'full': 66,
#  'videos': 1,
#  'house': 132,
#  'sunglasses': 277,
#  'flowered': 26,
#  'sit': 358,
#  'nearby': 152,
#  'left': 89,
#  'adults': 105,
#  'perhaps': 2,
#  'display': 43,
#  'case': 19,
#  'digital': 7,
#  'glass': 61,
#  'sides': 23,
#  'holds': 463,
#  'sideways': 18,
#  'arm': 147,
#  'snowboarder': 237,
#  'ramp': 318,
#  'snowboard': 88,
#  'performing': 193,
#  'trick': 383,
#  'making': 153,
#  'icy': 18,
#  'mountain': 556,
#  'climbers': 27,
#  'line': 152,
#  'their': 678,
#  'way': 52,
#  'covered': 370,
#  'background': 591,
#  'facing': 54,
#  'jumping': 1472,
#  'hoop': 55,
#  'ring': 69,
#  'using': 64,
#  'laptop': 12,
#  'cellphone': 97,
#  'against': 198,
#  'use': 7,
#  'electronics': 3,
#  'bench': 375,
#  'engage': 4,
#  'electronic': 10,
#  'devices': 3,
#  'races': 45,
#  'number': 110,
#  '6': 9,
#  'greyhound': 84,
#  'muzzle': 36,
#  'six': 77,
#  'tan': 392,
#  'gold': 60,
#  'muxzzled': 1,
#  'edge': 170,
#  'cliff': 194,
#  'scouts': 3,
#  'rest': 24,
#  'bluff': 5,
#  'overlooking': 104,
#  'top': 488,
#  'couple': 247,
#  'wooded': 101,
#  'them': 256,
#  'lined': 39,
#  'friends': 23,
#  'stroll': 3,
#  'forest': 160,
#  'path': 322,
#  'woods': 211,
#  'sponsored': 9,
#  'riwal': 1,
#  'smoking': 67,
#  'tires': 25,
#  'drives': 45,
#  'rain': 51,
#  'driving': 74,
#  'headlights': 3,
#  'advertising': 11,
#  'rainy': 5,
#  'lights': 40,
#  'raceway': 4,
#  'bearded': 46,
#  'whilst': 151,
#  'bicycle': 416,
#  'bicycles': 53,
#  'hair': 414,
#  'gives': 33,
#  'peace': 28,
#  'sign': 240,
#  'cap': 194,
#  'flashing': 2,
#  'crowd': 524,
#  'waving': 50,
#  'flags': 76,
#  'passing': 31,
#  'under': 244,
#  'bridge': 141,
#  'or': 87,
#  'banners': 7,
#  'gets': 107,
#  'pull': 32,
#  'chair': 133,
#  'meal': 14,
#  'table': 257,
#  'cafe': 18,
#  'restaurant': 80,
#  'eatery': 1,
#  'getting': 119,
#  'grabs': 16,
#  'seat': 50,
#  'racket': 52,
#  'round': 49,
#  'handle': 10,
#  'playes': 1,
#  'stringless': 1,
#  'backyard': 67,
#  'lawn': 115,
#  'clothing': 128,
#  'yard': 201,
#  'toys': 49,
#  'enjoy': 21,
#  'themselves': 23,
#  'wind': 18,
#  'blows': 41,
#  'trampoline': 114,
#  'blonde': 200,
#  'twirl': 2,
#  'bicyclists': 24,
#  'between': 124,
#  'wire': 39,
#  'fences': 4,
#  'cyclists': 26,
#  'country': 36,
#  'electricity': 1,
#  'pylon': 2,
#  'desert': 54,
#  'bikers': 30,
#  'dry': 79,
#  'land': 28,
#  'climbing': 503,
#  'steep': 61,
#  'hill': 443,
#  'climbs': 200,
#  'great': 10,
#  'dane': 3,
#  'spins': 15,
#  'merry': 21,
#  'go': 76,
#  'childern': 1,
#  'watch': 237,
#  'fathers': 2,
#  'spinning': 34,
#  'playground': 201,
#  'that': 394,
#  'skirt': 79,
#  'golden': 110,
#  'retriever': 37,
#  'excitedly': 2,
#  'greeting': 2,
#  'towards': 247,
#  'away': 169,
#  'greet': 4,
#  'dooorway': 1,
#  'bus': 81,
#  'onward': 3,
#  'door': 60,
#  'vehicle': 78,
#  'glancing': 2,
#  'window': 138,
#  'trolley': 1,
#  'passengers': 8,
#  'peaking': 4,
#  'peering': 4,
#  'hiding': 13,
#  'peeking': 9,
#  'striped': 220,
#  'peeks': 11,
#  'hold': 87,
#  'drinks': 59,
#  'point': 15,
#  'bottles': 11,
#  'several': 308,
#  'this': 141,
#  'photo': 92,
#  'beers': 5,
#  'border': 9,
#  'collie': 30,
#  'bed': 156,
#  'tennis': 429,
#  'climber': 124,
#  'peak': 20,
#  'rocks': 257,
#  'snowcapped': 13,
#  'hikes': 13,
#  'following': 22,
#  'surrounded': 177,
#  'distance': 109,
#  'smoke': 43,
#  'comes': 23,
#  'starts': 8,
#  'broken': 14,
#  'during': 171,
#  'badly': 1,
#  'racetrack': 52,
#  'bull': 49,
#  'branded': 2,
#  'leaves': 141,
#  'bags': 79,
#  'igloo': 5,
#  'cave': 21,
#  'luggage': 14,
#  'overnight': 1,
#  'stay': 4,
#  'backpacks': 32,
#  'piled': 4,
#  'ice': 216,
#  'visible': 14,
#  'hole': 37,
#  'starting': 16,
#  'steps': 155,
#  'murky': 15,
#  'putting': 35,
#  'legs': 133,
#  'pond': 96,
#  'busy': 99,
#  'city': 315,
#  'silhouette': 20,
#  'buildings': 70,
#  'crowded': 76,
#  'thre': 1,
#  'shot': 59,
#  'turned': 20,
#  'chases': 98,
#  'threw': 5,
#  'interacting': 9,
#  'opposite': 28,
#  'direction': 26,
#  'fetch': 31,
#  'also': 20,
#  'outdoors': 173,
#  'cameras': 13,
#  'third': 38,
#  'river': 233,
#  'skis': 82,
#  'backdrop': 9,
#  'face': 482,
#  'rope': 248,
#  'swimming': 441,
#  'creek': 43,
#  'rotweiler': 2,
#  'playfully': 32,
#  'rolls': 26,
#  'int': 6,
#  'chewing': 46,
#  'resting': 44,
#  'game': 361,
#  'elderly': 84,
#  'straw': 29,
#  'alone': 35,
#  'park': 507,
#  'haired': 202,
#  'gray': 158,
#  'dark': 265,
#  'beard': 66,
#  'guitar': 163,
#  'attractive': 4,
#  'halo': 2,
#  'head': 371,
#  'ceiling': 8,
#  'wide': 54,
#  'drink': 107,
#  'upward': 7,
#  'reading': 92,
#  'paperback': 3,
#  'book': 77,
#  'elder': 4,
#  'scarf': 88,
#  'older': 224,
#  'reads': 46,
#  'consulting': 1,
#  'looker': 1,
#  'motocross': 50,
#  'spill': 1,
#  'zipping': 1,
#  'slips': 1,
#  'motorcycle': 244,
#  'tight': 11,
#  'turn': 70,
#  'motorbike': 39,
#  'bright': 122,
#  'someone': 158,
#  'fall': 41,
#  'rider': 183,
#  'accident': 2,
#  'cots': 3,
#  'sleeping': 59,
#  'makeshift': 6,
#  'beds': 3,
#  'hanging': 163,
#  'mountainside': 26,
#  'skateboarder': 314,
#  'skateboard': 435,
#  'hopes': 3,
#  'landing': 27,
#  'teenage': 71,
#  'flipping': 16,
#  'tricks': 100,
#  'colored': 219,
#  'protest': 17,
#  'banner': 18,
#  'staring': 57,
#  'religious': 10,
#  'sidewalk': 374,
#  'poster': 13,
#  'word': 1,
#  'mambo': 3,
#  'image': 21,
#  'teddy': 8,
#  'bear': 28,
#  'showing': 41,
#  'humping': 3,
#  'stool': 15,
#  'trying': 160,
#  'sell': 6,
#  'animals': 42,
#  'selling': 12,
#  'various': 19,
#  'vendor': 12,
#  'sells': 5,
#  's': 400,
#  'visitors': 2,
#  'inflatable': 73,
#  'guy': 206,
#  'navy': 14,
#  'shorts': 377,
#  'pool': 687,
#  'football': 480,
#  'trunks': 92,
#  'strange': 14,
#  'antics': 1,
#  'diving': 70,
#  'plastic': 130,
#  'slide': 303,
#  'portion': 2,
#  'equipment': 85,
#  'shaded': 4,
#  'fire': 109,
#  'baton': 4,
#  'day': 136,
#  'juggling': 9,
#  'flames': 14,
#  'bubbles': 89,
#  'float': 29,
#  'popping': 8,
#  'woven': 5,
#  'toboggan': 4,
#  'knitted': 2,
#  'right': 94,
#  'poof': 1,
#  'woolen': 1,
#  'shoes': 91,
#  'sandals': 21,
#  'tug': 44,
#  'war': 37,
#  'pulling': 110,
#  'end': 52,
#  'rottweiler': 6,
#  'surf': 77,
#  'wave': 317,
#  'surfers': 21,
#  'surfing': 97,
#  'attempting': 56,
#  'sea': 29,
#  'huge': 92,
#  'sunset': 90,
#  'rides': 456,
#  'biking': 28,
#  'dirtbikes': 1,
#  'muddy': 81,
#  'slope': 76,
#  'crossing': 58,
#  'buses': 4,
#  'headwraps': 2,
#  'hurrying': 3,
#  'heads': 47,
#  'night': 153,
#  'phone': 52,
#  'talks': 51,
#  'pile': 76,
#  'rail': 103,
#  'snowpile': 1,
#  'stunt': 88,
#  'soccer': 580,
#  'uniform': 261,
#  'kick': 75,
#  'match': 41,
#  'watches': 275,
#  'knee': 21,
#  'female': 102,
#  'break': 33,
#  'driver': 26,
#  'wheel': 65,
#  'thumbs': 22,
#  'before': 42,
#  'polka': 16,
#  'dots': 5,
#  'boots': 66,
#  'hurridly': 1,
#  'hip': 4,
#  'kimono': 3,
#  'purse': 37,
#  'followed': 17,
#  'redheaded': 22,
#  'pedestrians': 11,
#  'meandering': 2,
#  'casually': 4,
#  'barefoot': 45,
#  'cute': 9,
#  'puppy': 100,
#  'fetches': 8,
#  'chew': 16,
#  'fluffy': 63,
#  'rings': 12,
#  'dock': 93,
#  'laughing': 95,
#  'bucket': 62,
#  'splashes': 70,
#  'pier': 34,
#  'beneath': 17,
#  'dances': 51,
#  'room': 129,
#  'balloons': 28,
#  'floor': 153,
#  'socks': 9,
#  'wooden': 284,
#  'strewn': 8,
#  'strings': 6,
#  'confetti': 6,
#  'bluejean': 1,
#  'wood': 73,
#  'mother': 43,
#  'chinatown': 1,
#  'both': 83,
#  'awnings': 2,
#  'ledge': 76,
#  'scales': 17,
#  'tent': 83,
#  'being': 328,
#  'enter': 8,
#  'fishing': 107,
#  'setting': 82,
#  'hut': 12,
#  'iced': 3,
#  'tarp': 8,
#  'structure': 76,
#  'surface': 65,
#  'few': 56,
#  'foam': 20,
#  'statue': 61,
#  'liberty': 4,
#  'hats': 91,
#  'statute': 2,
#  'crowns': 1,
#  'take': 80,
#  'photos': 10,
#  'new': 11,
#  'york': 3,
#  'get': 107,
#  'taken': 30,
#  'fight': 78,
#  'daschunds': 1,
#  'wiener': 2,
#  'jersey': 112,
#  'leaps': 204,
#  'dives': 22,
#  'going': 147,
#  'begin': 4,
#  'sheer': 16,
#  'climb': 89,
#  'pretty': 6,
#  'flat': 14,
#  'rocky': 245,
#  'card': 6,
#  'know': 2,
#  'what': 19,
#  'picure': 1,
#  'says': 43,
#  'referring': 1,
#  'periods': 1,
#  'they': 119,
#  'bathing': 119,
#  'suit': 245,
#  'sprinklers': 20,
#  'sprinkler': 53,
#  'sliding': 121,
#  'paddling': 48,
#  'kiddie': 21,
#  'lone': 82,
#  'flies': 101,
#  'leafless': 5,
#  'pulled': 38,
#  'shovel': 15,
#  'scoop': 2,
#  'skyward': 2,
#  'distorted': 8,
#  'open': 190,
#  'ends': 10,
#  'bottom': 44,
#  'just': 45,
#  'reaching': 41,
#  'lands': 16,
#  'reaches': 38,
#  'piano': 9,
#  'sings': 16,
#  'harpsichord': 1,
#  'preparing': 36,
#  'sing': 12,
#  'singer': 9,
#  'pianist': 1,
#  'music': 34,
#  'bares': 4,
#  'teeth': 44,
#  'tongue': 107,
#  'expanse': 3,
#  'curly': 39,
#  'violin': 31,
#  'boe': 1,
#  'transparent': 2,
#  'walls': 18,
#  'posters': 6,
#  'rubbing': 5,
#  'chin': 8,
#  'be': 77,
#  'cover': 19,
#  'teenager': 24,
#  'struggles': 6,
#  'carry': 17,
#  'piggy': 6,
#  'walkng': 1,
#  'paved': 43,
#  'covering': 35,
#  'arab': 4,
#  'turban': 3,
#  'facial': 11,
#  'palestinian': 1,
#  'style': 16,
#  'headscarf': 26,
#  'grey': 247,
#  'bird': 188,
#  'majestically': 1,
#  'waves': 141,
#  'roll': 10,
#  'crane': 15,
#  'upon': 4,
#  'onto': 211,
#  'pole': 153,
#  'swings': 121,
#  'silver': 65,
#  'swinging': 146,
#  'bounces': 8,
#  'leotard': 11,
#  'straddle': 2,
#  'split': 5,
#  'hello': 7,
#  'kitty': 7,
#  'does': 230,
#  'leg': 58,
#  'splits': 9,
#  'leans': 57,
#  'board': 142,
#  'platform': 48,
#  'skateboarders': 11,
#  'eating': 144,
#  'seeds': 6,
#  'eats': 52,
#  'sunflower': 1,
#  'clinging': 5,
#  'stone': 128,
#  'friend': 30,
#  'helps': 29,
#  'help': 20,
#  'learning': 4,
#  'how': 17,
#  'helping': 24,
#  'sweatshirt': 77,
#  'competitor': 2,
#  'not': 18,
#  'far': 12,
#  'racer': 48,
#  'slightly': 16,
#  'competition': 51,
#  'circuit': 8,
#  'dirtbike': 1,
#  'cheering': 10,
#  'grabbing': 15,
#  'ankle': 7,
#  'oklahoma': 18,
#  'score': 10,
#  'fans': 21,
#  'cheer': 11,
#  'endzone': 1,
#  'athlete': 15,
#  'performs': 96,
#  'launching': 1,
#  'herself': 20,
#  'bar': 107,
#  'vault': 4,
#  'vaulting': 3,
#  'vaulter': 1,
#  'upside': 109,
#  'attempts': 54,
#  'feet': 87,
#  'do': 50,
#  'gap': 3,
#  'flip': 94,
#  'blocks': 26,
#  'concrete': 117,
#  'carefully': 6,
#  'crosses': 25,
#  'reflection': 14,
#  'cinderblock': 1,
#  'caught': 28,
#  'pajamas': 18,
#  'hall': 9,
#  ...}

# %%
f.convert_sentence_to_tokens("the dog crosses the street")
# Out:
# [10, 4, 994, 10, 91, 0]

# %%
f.w2i['the']
# Out:
# 10

# %%
f.i2w[10]
# Out:
# 'the'

# %% [markdown]
# ### Now let's setup our Net

# %%
net = IC_V6(f.tokens)

# %%
net.load_state_dict(torch.load('models/epochs_40_loss_2_841_v6.pth'))

# %%
if(USE_GPU):
    net.cuda()
    inception.cuda()

# %%
net.eval()
# Out:
# IC_V6(
#   (batchnorm): BatchNorm1d(300, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (input_embedding): Embedding(8385, 300)
#   (embedding_dropout): Dropout(p=0.22)
#   (gru): GRU(300, 300, num_layers=3, dropout=0.22)
#   (linear): Linear(in_features=300, out_features=300, bias=True)
#   (out): Linear(in_features=300, out_features=8385, bias=True)
# )

# %%
#traindataset
random_train_index =  np.random.randint(len(f.training_data))
train_filename = 'Flicker8k_Dataset/'+f.training_data[random_train_index]['filename']

print("Original caption: ",f.training_data[random_train_index]['sentences'][0]['raw'])
print("")
print("Greedy caption:", f.caption_image_greedy(net, train_filename))
print("")
print("Beam caption:")
f.print_beam_caption(net, train_filename)

IPython.display.Image(filename=train_filename)
# Out:
# Original caption:  A girl in hot pink leotard is leaping through the air .
#
# Greedy caption: a gymnast jumps high in the air
#
# Beam caption:
# a gymnast in the air in front of [ -8.617265462875366 ]
# a girl in front of a blue and [ -9.26070187985897 ]
# a gymnast in the air in a hoop [ -9.697504997253418 ]
# a gymnast in the air in a soccer [ -10.053638935089111 ]
# a girl in front of a blue soccer [ -10.354189619421959 ]
# a gymnast in the air in a girl [ -10.460629224777222 ]
# a gymnast in the air at a hoop [ -10.477128982543945 ]
# a girl in the air in a hoop [ -10.504448890686035 ]
# a gymnast in the air in a volleyball [ -10.637203931808472 ]
# a girl in front of a volleyball in [ -10.752586349844933 ]

# %%
#test dataset
random_test_index = np.random.randint(len(f.test_data))
test_filename = IMAGE_DIR+f.test_data[random_test_index]['filename']
print("Original caption: ",f.test_data[random_test_index]['sentences'][0]['raw'])
print("")
print("Greedy caption:", f.caption_image_greedy(net,test_filename))
print("")
print("Beam caption:")
f.print_beam_caption(net, test_filename, 10)
IPython.display.Image(filename=test_filename)
# Out:
# Original caption:  A man is sitting on the floor outside a door and his head on his chin .
#
# Greedy caption: a man and a woman are sitting on a bench
#
# Beam caption:
# a man a man is sitting on [ -7.795112133026123 ]
# a man a woman sitting on a [ -7.962974309921265 ]
# a woman in a woman sitting on [ -8.000674724578857 ]
# a man a young girl sitting on [ -8.42231035232544 ]
# a woman in a woman with a [ -8.441170454025269 ]
# a man a man is sitting in [ -8.518628120422363 ]
# a man is sitting on a bench [ -8.535754680633545 ]
# a man is sitting on a couch [ -8.681111812591553 ]
# a woman in a woman sitting in [ -8.724190711975098 ]
# a man is sitting on a train [ -8.780120372772217 ]

# %%
train_filename = 'my-images/phone.jpeg'
print("Greedy caption:", f.caption_image_greedy(net,train_filename))
print("")
print("Beam caption:")
f.print_beam_caption(net, train_filename, 3)
IPython.display.Image(filename=train_filename)
# Out:
# Greedy caption: a group of people are watching a fire
#
# Beam caption:
# a group of people in a game in [ -10.175615072250366 ]
# a group of people in a instruments in [ -10.235952615737915 ]
# a group of people in a game with [ -10.271355390548706 ]

# %%
train_filename = 'my-images/2019-04-24.jpeg'
print("Greedy caption:", f.caption_image_greedy(net,train_filename))
print("")
print("Beam caption:")
f.print_beam_caption(net, train_filename, 3)
IPython.display.Image(filename=train_filename)
# Out:
# Greedy caption: a baby is playing with a toy
#
# Beam caption:
# a baby are sitting on a [ -5.3513911962509155 ]
# a baby are playing in a [ -5.706337094306946 ]
# a baby play on a game [ -5.835863828659058 ]

# %% [markdown]
# ## Train the network

# %%
l = torch.nn.CrossEntropyLoss(reduction='none')
o = optim.Adam(net.parameters(), lr=0.0001)

# %%
if(USE_GPU):
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

#Only Train 1 Epoch to speed up
epochs = 1

inception.eval()
net.train()

loss_so_far = 0.0

total_samples = len(f.training_data)

for epoch in range(epochs):
    for (image_tensor, tokens, _, index) in f.return_train_batch():
        o.zero_grad()
        net.zero_grad()

        words = []
        loss=0.

        input_token = f.w2i[STARTWORD]
        input_tensor = torch.tensor(input_token).to(device)

        for token in tokens:
            if(input_token==f.w2i[STARTWORD]):
                out, hidden=net(input_tensor, image_tensor.to(device), process_image=True)
            else:
                out, hidden=net(input_tensor, hidden)

            class_label = torch.tensor(token).to(device).view(1)
            input_token = token
            input_tensor = torch.tensor(input_token).to(device)

            out = out.squeeze().view(1,-1)
            loss += l(out,class_label)

        loss = loss/len(tokens)

        loss.backward()
        o.step()

        loss_so_far += loss.detach().item()

        if(np.random.rand()<0.002): #5% of cases
            print("\n Epoch: ",epoch, ", index: ", index," loss: ",round(loss.detach().item(),3)," | running avg loss: ", round(loss_so_far/((epoch*total_samples)+(index+1)),3))

            torch.save(net.state_dict(), 'models/running_save_v6.pth')
            torch.save(net.state_dict(), 'models/running_inception_save_v6.pth')

            net.eval()
           
            #test dataset
            #random_train_index = np.random.randint(len(f.training_data))
            random_train_index = index
            train_filename = IMAGE_DIR+f.training_data[random_train_index]['filename']
            print("Original caption: ")
            [print(x['raw'].lower()) for x in f.training_data[random_train_index]['sentences']]
            print("")
            print("Greedy caption:", f.caption_image_greedy(net,train_filename))
            print("")
            print("Beam caption:")
            f.print_beam_caption(net, train_filename, 3)
            #IPython.display.Image(filename=test_filename) 
            IPython.display.Image(filename=train_filename) 
            net.train()
    
    print("\n\n")
    print("==== EPOCH DONE. === ")
    print("\n\n")
# Out:
#  Epoch:  0 , index:  775  loss:  3.096  | running avg loss:  2.785
# Original caption:
# a man and a woman wearing masks embrace at an outdoor festival .
# a man and woman dressed up dance together outdoors .
# two people acting out a scene in front of an audience .
# two people in masks dancing .
# two people in middle eastern garb embrace on a crowded lawn .
#
# Greedy caption: a group of people are standing in front of a crowd of people
#
# Beam caption:
# a group of people in front of a [ -8.501312017440796 ]
# a group of people are playing with the [ -8.616613507270813 ]
# a group of people are playing with a [ -8.695545315742493 ]
#
#  Epoch:  0 , index:  794  loss:  2.805  | running avg loss:  2.783
# Original caption:
# a born dog carries some fruit in his mouth while two other dogs follow him .
# one dog carries a ball as it is being chased by two more dogs .
# three dogs play in the park with the brown dog getting the ball .
# two dogs chase another dog that has a ball .
# two large dogs chase after another dog that has a ball in his mouth and runs from them .
#
# Greedy caption: a brown dog is running on a beach
#
# Beam caption:
# two dogs are playing in a war with [ -7.506886839866638 ]
# a brown dog running on a war with [ -7.767783522605896 ]
# a dog is running on a war with [ -7.791555285453796 ]
#
#  Epoch:  0 , index:  1078  loss:  2.145  | running avg loss:  2.799
# Original caption:
# a brown dog in a pink shirt chews something white while a brown dog in yellow watches .
# a brown dog wearing a pink shirt is followed by a brown dog wearing a yellow shirt .
# a dog in a pink shirt with something white in his mouth and a dog in a yellow shirt .
# the two dogs with clothing are in a flat uncut field .
# two dogs fetching an object in a field .
#
# Greedy caption: a dog is running through the grass
#
# Beam caption:
# a black dogs are playing in the grass [ -7.211032867431641 ]
# a brown dogs are playing in the grass [ -7.436903953552246 ]
# two dogs are playing in a grassy field [ -7.5338051319122314 ]
#
#  Epoch:  0 , index:  1946  loss:  1.389  | running avg loss:  2.816
# Original caption:
# a brown dog jumps over colorful poles and numbered cones .
# a dog jumping over an obstacle hurdle .
# a large tan dog is jumping over hurdles on a course .
# a tan dog jumping over an obstacle .
# a tan dog jumps over a purple and green gate .
#
# Greedy caption: a dog jumps over a hurdle
#
# Beam caption:
# a dog jump over a [ -4.579215586185455 ]
# a dog jumping over a [ -4.8238402009010315 ]
# a dog play in a [ -5.122552394866943 ]
#
#  Epoch:  0 , index:  2640  loss:  3.038  | running avg loss:  2.836
# Original caption:
# a child wearing a yellow jacket is jumping down from a rock .
# a kid in a yellow jacket and blue baseball cap jumping from a rock .
# a young boy jumps into water .
# boy wearing yellow jacket jumping .
# little kid with yellow jacket and blue hat jumping off rock
#
# Greedy caption: a young boy in a red shirt is jumping over a hurdle
#
# Beam caption:
# a young boys are playing with a [ -7.821885704994202 ]
# a young boys are playing on the [ -8.032189965248108 ]
# a young boys are playing in the [ -8.077151238918304 ]
#
#  Epoch:  0 , index:  2743  loss:  1.096  | running avg loss:  2.838
# Original caption:
# a black dog is looking down at another black dog lying on the grass .
# two big black dogs play with each other in the grass .
# two black dogs are frolicking around the grass together .
# two black dogs are playing on the grass .
# two black dogs play together on a lawn
#
# Greedy caption: a black dog is running through the grass
#
# Beam caption:
# a black dogs are playing [ -4.069884538650513 ]
# a black dogs run through [ -4.545520782470703 ]
# a black dogs play with [ -4.709551095962524 ]
#
#  Epoch:  0 , index:  2983  loss:  3.77  | running avg loss:  2.843
# Original caption:
# a pair of young women with an easel give a lecture to a young audience .
# two girls are using a flip chart whilst talking to some younger children .
# two girls doing a presentation
# two young woman perform near handwritten notice as little girls watch .
# two young women with a large piece of paper .
#
# Greedy caption: a man in a black shirt and a woman in a black shirt
#
# Beam caption:
# a group of people posing for a bench [ -7.742752552032471 ]
# a group of people sitting on a bench [ -8.541459321975708 ]
# a group of people are sitting on a [ -8.778057932853699 ]
#
#  Epoch:  0 , index:  3378  loss:  1.488  | running avg loss:  2.845
# Original caption:
# a girl in a white shirt jumps on a trampoline .
# a young girl bouncing on a trampoline .
# a young girl jumping on an enclosed trampoline
# the girl in blue jeans and white shirt is balancing on one leg .
# we cannot see the face of the girl with the white t-shirt and blue jeans .
#
# Greedy caption: a young girl jumping on a trampoline
#
# Beam caption:
# a young girl jump on a trampoline [ -6.679653167724609 ]
# a young man in front of a [ -7.206081390380859 ]
# a young man with a trampoline trampoline [ -8.45677125453949 ]
#
#  Epoch:  0 , index:  4386  loss:  4.077  | running avg loss:  2.849
# Original caption:
# a little boy is putting some cutout letters on the wall .
# a small child is playing with cut-outs of the letter " p. "
# a toddler sticks paper " p " letters to a wood paneled wall .
# the child is sticking paper letters to a wooden wall .
# toddler in pajamas plays with paper cutouts of the letter " p " .
#
# Greedy caption: a little boy is sitting on a bed
#
# Beam caption:
# a little girl is sitting on a paper [ -9.399807453155518 ]
# a little boy is sitting on a paper [ -9.410088539123535 ]
# a little girl is sitting on a colored [ -10.569103717803955 ]
#
#  Epoch:  0 , index:  4535  loss:  3.371  | running avg loss:  2.849
# Original caption:
# a red boat is paddled down the rapids by two people .
# two canooers paddle through some rapids .
# two people in jackets are rowing a canoe down a river .
# two people rafting down a river near pine trees .
# two people row a boat past rocks in water .
#
# Greedy caption: a man in a yellow kayak paddling through the water
#
# Beam caption:
# a group of people are sitting on a [ -7.383779525756836 ]
# a group of people are sitting on the [ -7.446145057678223 ]
# a group of people are sitting in the [ -7.569918632507324 ]
#
#  Epoch:  0 , index:  4680  loss:  2.973  | running avg loss:  2.851
# Original caption:
# a blond boy petting a tiger
# a boy pets a sleeping tiger .
# a boy pets a sleeping tiger while another tiger sleeps behind him .
# a little blonde boy is petting a resting tiger .
# a little boy is petting a tiger that is laying down .
#
# Greedy caption: a man and a woman are sitting on a bench
#
# Beam caption:
# a man is sitting on a shopping cart [ -9.65608024597168 ]
# a white and white bench while another cellphone [ -9.94497013092041 ]
# a man with a bench on a cellphone [ -10.162866592407227 ]
#
#  Epoch:  0 , index:  4706  loss:  3.207  | running avg loss:  2.851
# Original caption:
# two people are walking in a desert .
# two people are walking through the sand .
# two people , one with a black jacket and one with a blue headscarf , are walking along a desert-like area .
# two people walking along a huge desert with a statue in the distance .
# two people walk out onto the desert sand .
#
# Greedy caption: a man stands on a rocky hill
#
# Beam caption:
# a man stands in front of a mountain [ -6.579742133617401 ]
# a man stands on top of a mountain [ -7.412536382675171 ]
# a man stands in front of a view [ -8.015945136547089 ]
#
#  Epoch:  0 , index:  4948  loss:  2.283  | running avg loss:  2.855
# Original caption:
# a child with a pink hat and a white and pink shirt standing in grass .
# a little girl in a football jersy and pink snow hat is standing on a football field .
# a small child wearing a pink hat , bluejeans , and white shirt standing in a grass field .
# a young girl wearing a pink hat stands on a grassy field .
# a young girl with a pink hat on with a yellow building in the background .
#
# Greedy caption: a boy in a blue shirt is running through a field
#
# Beam caption:
# a young boy in the middle of a [ -8.578827023506165 ]
# a boy a boy in the middle of [ -8.664649605751038 ]
# a young boy in the grass field of [ -9.177293300628662 ]
#
#  Epoch:  0 , index:  5613  loss:  1.639  | running avg loss:  2.856
# Original caption:
# a basketball player defends another player .
# a man with a basketball blocks an attempt to take his ball .
# man runs by other man with basketball at a game .
# the player in the white dribbles the ball , while the player in the orange tries to stop him .
# two men are playing during a basketball game .
#
# Greedy caption: a basketball player in a white uniform is running
#
# Beam caption:
# a basketball players are playing a [ -3.5159887075424194 ]
# a basketball players playing basketball in [ -3.9817439317703247 ]
# a basketball players playing basketball on [ -4.109891057014465 ]
#
#
#
# ==== EPOCH DONE. ===

# %% [markdown]
# ## Save the network

# %%
torch.save(net.state_dict(), 'models/epochs_20_loss_2_841_v6.pth')
torch.save(inception.state_dict(), 'models/inception_epochs_20.pth')

# %% [markdown]
# ## Helper functions for visualizations

# %%
def rand_cmap(nlabels, type='bright', first_color_black=True, last_color_black=False, verbose=True):
    """
    Creates a random colormap to be used together with matplotlib. Useful for segmentation tasks
    :param nlabels: Number of labels (size of colormap)
    :param type: 'bright' for strong colors, 'soft' for pastel colors
    :param first_color_black: Option to use first color as black, True or False
    :param last_color_black: Option to use last color as black, True or False
    :param verbose: Prints the number of labels and shows the colormap. True or False
    :return: colormap for matplotlib
    """
    from matplotlib.colors import LinearSegmentedColormap
    import colorsys
    import numpy as np


    if type not in ('bright', 'soft'):
        print ('Please choose "bright" or "soft" for type')
        return

    if verbose:
        print('Number of labels: ' + str(nlabels))

    # Generate color map for bright colors, based on hsv
    if type == 'bright':
        randHSVcolors = [(np.random.uniform(low=0.0, high=1),
                          np.random.uniform(low=0.2, high=1),
                          np.random.uniform(low=0.9, high=1)) for i in range(nlabels)]

        # Convert HSV list to RGB
        randRGBcolors = []
        for HSVcolor in randHSVcolors:
            randRGBcolors.append(colorsys.hsv_to_rgb(HSVcolor[0], HSVcolor[1], HSVcolor[2]))

        if first_color_black:
            randRGBcolors[0] = [0, 0, 0]

        if last_color_black:
            randRGBcolors[-1] = [0, 0, 0]

        random_colormap = LinearSegmentedColormap.from_list('new_map', randRGBcolors, N=nlabels)

    # Generate soft pastel colors, by limiting the RGB spectrum
    if type == 'soft':
        low = 0.6
        high = 0.95
        randRGBcolors = [(np.random.uniform(low=low, high=high),
                          np.random.uniform(low=low, high=high),
                          np.random.uniform(low=low, high=high)) for i in xrange(nlabels)]

        if first_color_black:
            randRGBcolors[0] = [0, 0, 0]

        if last_color_black:
            randRGBcolors[-1] = [0, 0, 0]
        random_colormap = LinearSegmentedColormap.from_list('new_map', randRGBcolors, N=nlabels)

    # Display colorbar
    if verbose:
        from matplotlib import colors, colorbar
        from matplotlib import pyplot as plt
        fig, ax = plt.subplots(1, 1, figsize=(15, 0.5))

        bounds = np.linspace(0, nlabels, nlabels + 1)
        norm = colors.BoundaryNorm(bounds, nlabels)

        cb = colorbar.ColorbarBase(ax, cmap=random_colormap, norm=norm, spacing='proportional', ticks=None,
                                   boundaries=bounds, format='%1i', orientation=u'horizontal')

    return random_colormap

# %% [markdown]
# ## Start visualizations (First of word embeddings)

# %%
frequency_threshold = 50 #the word should have appeared at least this many times for us to visualize

all_word_embeddings = []
all_words = []

for word in f.word_frequency.keys():
    if(f.word_frequency[word]>=frequency_threshold):
        all_word_embeddings.append(net.input_embedding(torch.tensor(f.w2i[word]).to(device)).detach().to('cpu').numpy())
        all_words.append(word)

# %%
len(all_words)
# Out:
# 701

# %%
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)

# %%
X_2d = tsne.fit_transform(all_word_embeddings)

# %%
new_cmap = rand_cmap(10, type='bright', first_color_black=True, last_color_black=False, verbose=True)
# Out:
# Number of labels: 10
# FigureCanvasNbAgg()

# %%
fig,ax = plt.subplots(figsize=(7, 7))
    
sc = plt.scatter(X_2d[:,0], X_2d[:,1])
#plt.legend()
#plt.show()

annot = ax.annotate("", xy=(0,0), xytext=(20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->", color='red'))
annot.set_visible(False)

def update_annot(ind):

    pos = sc.get_offsets()[ind["ind"][0]]
    annot.xy = pos
    text = "{}".format(" ".join([all_words[n] for n in ind["ind"]]))
    annot.set_text(text)
    annot.get_bbox_patch().set_facecolor('white')
    annot.get_bbox_patch().set_alpha(0.9)


def hover(event):
    
    vis = annot.get_visible()
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        if cont:
            
            
            update_annot(ind)
            
            annot.set_visible(True)
            fig.canvas.draw_idle()
        else:
            
            if vis:
                annot.set_visible(False)
                fig.canvas.draw_idle()
                
def onpick(event):
    ind = event.ind
    print(ind)
    label_pos_x = event.mouseevent.xdata
    label_pos_y = event.mouseevent.ydata
    annot.xy = (label_pos_x,label_pos_y)
    annot.set_text(y[ind])
    ax.figure.canvas.draw_idle()
    
    

fig.canvas.mpl_connect("motion_notify_event", hover)

#fig.canvas.mpl_connect('pick_event', onpick)

plt.show()
# Out:
# FigureCanvasNbAgg()

# %% [markdown]
# ## find top 5 closest words due to similarity

# %%
from scipy import spatial
def return_cosine_sorted(target_word_embedding):
    
    words = []
    cosines = []
    
    for i in range(len(all_word_embeddings)):
        cosines.append(1 - spatial.distance.cosine(target_word_embedding, all_word_embeddings[i]))
        
    sorted_indexes = np.argsort(cosines)[::-1]
    
    return np.vstack((np.array(all_words)[sorted_indexes], np.array(cosines)[sorted_indexes])).T

# %%
all_words[10]
# Out:
# 'chasing'

# %%
def return_similar_words(word, top_n=5):
    
    return return_cosine_sorted(return_embedding(word))[1:top_n+1]

# %%
def return_embedding(word):
    if(word in all_words):
        target_embedding_index = [i for i, s in enumerate(all_words) if word in s][0]
        return all_word_embeddings[target_embedding_index]
    else:
        return None

# %%
def return_analogy(source_word_1, source_word_2, target_word_1, top_n=5):
    
    em_sw_1 = return_embedding(source_word_1)
    em_sw_2 = return_embedding(source_word_2)
    em_tw_1 = return_embedding(target_word_1)
    
    if((em_sw_1 is None) | (em_sw_2 is None) | (em_tw_1 is None)):
        return 0
    
    target_embedding = em_tw_1 + (em_sw_2 - em_sw_1)
    return return_cosine_sorted(target_embedding)[1:top_n+1]

# %%
return_similar_words('boy')
# Out:
# array([['rider', '0.20570480823516846'],
#        ['kids', '0.1974964141845703'],
#        ['kid', '0.16924132406711578'],
#        ['shirts', '0.1670515388250351'],
#        ['toddler', '0.1642109751701355']], dtype='<U32')

# %%
return_analogy('green', 'grass', 'red')
# Out:
# array([['red', '0.5262780785560608'],
#        ['be', '0.16231581568717957'],
#        ['sandy', '0.1578163206577301'],
#        ['golden', '0.15509815514087677'],
#        ['kissing', '0.14484186470508575']], dtype='<U32')

# %% [markdown]
# ## embedding of images (visualize)

# %%
def cart2pol(x, y):
    rho = np.sqrt(x**2 + y**2)
    phi = np.arctan2(y, x)
    return(rho, phi)

def pol2cart(rho, phi):
    x = rho * np.cos(phi)
    y = rho * np.sin(phi)
    return(x, y)

# %%
import itertools
all_image_embeddings = []
all_image_filenames = []

for i in range(len(f.training_data)):
    all_image_embeddings.append(inception(f.image_to_tensor('Flicker8k_Dataset/'+f.training_data[i]['filename']).to(device)).detach().to('cpu').numpy())
    all_image_filenames.append(f.training_data[i]['filename'])

# %%
all_image_embeddings_temp = all_image_embeddings[:]
all_image_filenames_temp = all_image_filenames[:]

# %%
from matplotlib.offsetbox import (TextArea, DrawingArea, OffsetImage,
                                  AnnotationBbox)

# %%
from sklearn.manifold import TSNE
tsne_images = TSNE(n_components=2, random_state=0)

# %%
X_2d = tsne.fit_transform(np.squeeze(all_image_embeddings_temp))

# %%
fig,ax = plt.subplots(figsize=(10, 10))
    
sc = plt.scatter(X_2d[:,0], X_2d[:,1])


annot = ax.annotate("", xy=(0,0), xytext=(20,20),textcoords="offset points",
                    bbox=dict(boxstyle="round", fc="w"),
                    arrowprops=dict(arrowstyle="->", color='red'))
annot.set_visible(False)

def update_annot(ind):

    pos = sc.get_offsets()[ind["ind"][0]]
    annot.xy = pos
    #text = "{}".format(" ".join([all_words[n] for n in ind["ind"]]))
    #annot.set_text(text)
    
    rho = 10 #how for to draw centers of new images
    total_radians = 2* np.pi
    num_images = len(ind["ind"])
    if(num_images > 4): #at max 4
        num_images=4
    radians_offset = total_radians/num_images
    
    for i in range(num_images):    
        hovered_filename = 'Flicker8k_Dataset/'+all_image_filenames_temp[ind["ind"][i]]
        arr_img = Image.open(hovered_filename, 'r')

        imagebox = OffsetImage(arr_img, zoom=0.3)
        #imagebox.image.axes = ax
    
        offset = pol2cart(rho, i*radians_offset)
        new_xy = (pos[0]+offset[0], pos[1]+offset[1])
        ab = AnnotationBbox(imagebox, new_xy)

        ax.add_artist(ab)
        annot.get_bbox_patch().set_facecolor('white')
        annot.get_bbox_patch().set_alpha(0.9)

def hover(event):
    
    vis = annot.get_visible()
    if event.inaxes == ax:
        cont, ind = sc.contains(event)
        if cont:
            update_annot(ind)
            
            annot.set_visible(True)
            fig.canvas.draw_idle()
        else:
            if vis:
                annot.set_visible(False)
                remove_all_images()
                fig.canvas.draw_idle()

def remove_all_images():
    for obj in ax.findobj(match = type(AnnotationBbox(1, 1))):
        obj.remove()

fig.canvas.mpl_connect("motion_notify_event", hover)

#fig.canvas.mpl_connect('pick_event', onpick)

plt.show()
# Out:
# FigureCanvasNbAgg()

# %% [markdown]
# ## Similar images to a given image

# %%
def plot_image(filename):
    pil_im = Image.open(filename, 'r')
    plt.figure()
    plt.imshow(np.asarray(pil_im))
    plt.show()

# %%
def return_similar_images(image_filename, top_n=5):
    
    return return_cosine_sorted_image(return_embedding_image(image_filename))[1:top_n+1]

# %%
def return_cosine_sorted_image(target_image_embedding):
    cosines = []
    
    for i in range(len(all_image_embeddings)):
        cosines.append(1 - spatial.distance.cosine(target_image_embedding, all_image_embeddings[i]))
        
    sorted_indexes = np.argsort(cosines)[::-1]
    
    return np.vstack((np.array(all_image_filenames)[sorted_indexes], np.array(cosines)[sorted_indexes])).T

# %%
def return_embedding_image(image_filename):
    return inception(f.image_to_tensor(image_filename).to(device)).detach().to('cpu').numpy().squeeze()

# %%
search_filename = 'my-images/beach.jpg'
plot_image(search_filename)
# Out:
# FigureCanvasNbAgg()

# %%
similar_images = return_similar_images(search_filename)

# %%
plot_image('Flicker8k_Dataset/'+similar_images[0][0])
# Out:
# FigureCanvasNbAgg()

# %% [markdown]
# ## Search via captions

# %%
target_sentence = 'a child on a bike'
tokens= f.convert_sentence_to_tokens(target_sentence)

# %%
set_parameter_requires_grad(net, True)

# %%
embedding_tensor = torch.autograd.Variable(torch.randn(1,INPUT_EMBEDDING)*0.01, requires_grad=True).to(device)

# %%
l = torch.nn.CrossEntropyLoss(reduction='none')

# %%
print(embedding_tensor.shape)
# Out:
# torch.Size([1, 300])

# %%
epochs = 2000

loss_so_far = 0.0
lr = 0.001

#embedding_tensor = torch.autograd.Variable(embedding_tensor.clone()).to(device)

embedding_tensor = torch.autograd.Variable(embedding_tensor.clone(), requires_grad=True).to(device)

with torch.autograd.set_detect_anomaly(True):

    for epoch in range(epochs):
        
        input_token = f.w2i[STARTWORD]
        input_tensor = torch.tensor(input_token).to(device)

        loss=0.

        for token in tokens:

            if(input_token==f.w2i[STARTWORD]):
                out, hidden=net(input_tensor, embedding_tensor, process_image=True, use_inception=False)
            else:
                out, hidden=net(input_tensor, hidden)


            class_label = torch.tensor(token).view(1).to(device)

            input_token = token
            input_tensor = torch.tensor(input_token)


            out = out.squeeze().view(1,-1)

            loss = loss + l(out,class_label)


        #loss = loss/len(tokens)

        loss.backward()
        
        
        #print(image_tensor.grad)
        #print(embedding_tensor.shape)
        if embedding_tensor.grad is None:
            print("gradient is none")
        else:
            embedding_tensor = torch.autograd.Variable(embedding_tensor.clone() - lr * embedding_tensor.grad, requires_grad=True)
        
        #print(embedding_tensor.grad.shape)

        loss_so_far += loss.detach().item()

        if(epoch %10 ==0):
            print("==== Epoch: ", epoch, " loss: ",round(loss.detach().item(),3)," | running avg loss: ", round(loss_so_far/(epoch+1),3))
            if(epoch %100 ==0):
                similar_images = return_cosine_sorted_image(embedding_tensor.detach().to('cpu').numpy().squeeze())
                print(similar_images[:3])
                #plot_image('Flicker8k_Dataset/'+similar_images[0][0])
# Out:
# ==== Epoch:  0  loss:  13.592  | running avg loss:  13.592
# [['2970461648_fe14ba0359.jpg' '0.16050942242145538']
#  ['2624044128_641b38c0cf.jpg' '0.14377552270889282']
#  ['3666169738_a8c74cf745.jpg' '0.14346426725387573']]
# ==== Epoch:  10  loss:  11.248  | running avg loss:  12.288
# ==== Epoch:  20  loss:  11.414  | running avg loss:  11.949
# ==== Epoch:  30  loss:  9.638  | running avg loss:  11.667
# ==== Epoch:  40  loss:  10.918  | running avg loss:  11.361
# ==== Epoch:  50  loss:  9.804  | running avg loss:  11.077
# ==== Epoch:  60  loss:  10.19  | running avg loss:  10.89
# ==== Epoch:  70  loss:  9.144  | running avg loss:  10.739
# ==== Epoch:  80  loss:  9.407  | running avg loss:  10.541
# ==== Epoch:  90  loss:  8.516  | running avg loss:  10.36
# ==== Epoch:  100  loss:  9.232  | running avg loss:  10.222
# [['3432586199_e50b0d6cb7.jpg' '0.1972486972808838']
#  ['3373069977_bc73e9e409.jpg' '0.19338777661323547']
#  ['3606084228_6286a52875.jpg' '0.1903819441795349']]
# ==== Epoch:  110  loss:  7.323  | running avg loss:  10.057
# ==== Epoch:  120  loss:  7.936  | running avg loss:  9.897
# ==== Epoch:  130  loss:  7.389  | running avg loss:  9.753
# ==== Epoch:  140  loss:  7.999  | running avg loss:  9.633
# ==== Epoch:  150  loss:  8.12  | running avg loss:  9.52
# ==== Epoch:  160  loss:  7.941  | running avg loss:  9.408
# ==== Epoch:  170  loss:  7.536  | running avg loss:  9.326
# ==== Epoch:  180  loss:  7.558  | running avg loss:  9.236
# ==== Epoch:  190  loss:  7.981  | running avg loss:  9.16
# ==== Epoch:  200  loss:  7.286  | running avg loss:  9.073
# [['759015118_4bd3617e60.jpg' '0.22266526520252228']
#  ['2073174497_18b779999c.jpg' '0.21379709243774414']
#  ['3432586199_e50b0d6cb7.jpg' '0.20817257463932037']]
# ==== Epoch:  210  loss:  7.252  | running avg loss:  8.994
# ==== Epoch:  220  loss:  7.114  | running avg loss:  8.915
# ==== Epoch:  230  loss:  7.293  | running avg loss:  8.846
# ==== Epoch:  240  loss:  6.778  | running avg loss:  8.764
# ==== Epoch:  250  loss:  6.981  | running avg loss:  8.715
# ==== Epoch:  260  loss:  7.197  | running avg loss:  8.66
# ==== Epoch:  270  loss:  6.782  | running avg loss:  8.596
# ==== Epoch:  280  loss:  6.219  | running avg loss:  8.537
# ==== Epoch:  290  loss:  6.733  | running avg loss:  8.497
# ==== Epoch:  300  loss:  7.61  | running avg loss:  8.456
# [['3730457171_e66dde8c91.jpg' '0.23642073571681976']
#  ['759015118_4bd3617e60.jpg' '0.22930730879306793']
#  ['2073174497_18b779999c.jpg' '0.2237733155488968']]
# ==== Epoch:  310  loss:  6.785  | running avg loss:  8.421
# ==== Epoch:  320  loss:  7.549  | running avg loss:  8.379
# ==== Epoch:  330  loss:  6.787  | running avg loss:  8.326
# ==== Epoch:  340  loss:  6.769  | running avg loss:  8.289
# ==== Epoch:  350  loss:  7.527  | running avg loss:  8.247
# ==== Epoch:  360  loss:  7.076  | running avg loss:  8.205
# ==== Epoch:  370  loss:  6.8  | running avg loss:  8.164
# ==== Epoch:  380  loss:  6.184  | running avg loss:  8.132
# ==== Epoch:  390  loss:  6.381  | running avg loss:  8.103
# ==== Epoch:  400  loss:  6.381  | running avg loss:  8.07
# [['3730457171_e66dde8c91.jpg' '0.24851079285144806']
#  ['759015118_4bd3617e60.jpg' '0.22815482318401337']
#  ['2603334363_cfa32c4482.jpg' '0.221486434340477']]
# ==== Epoch:  410  loss:  7.585  | running avg loss:  8.041
# ==== Epoch:  420  loss:  5.727  | running avg loss:  8.012
# ==== Epoch:  430  loss:  6.721  | running avg loss:  7.979
# ==== Epoch:  440  loss:  5.923  | running avg loss:  7.958
# ==== Epoch:  450  loss:  6.891  | running avg loss:  7.931
# ==== Epoch:  460  loss:  6.794  | running avg loss:  7.906
# ==== Epoch:  470  loss:  6.949  | running avg loss:  7.88
# ==== Epoch:  480  loss:  7.459  | running avg loss:  7.857
# ==== Epoch:  490  loss:  5.674  | running avg loss:  7.829
# ==== Epoch:  500  loss:  6.928  | running avg loss:  7.807
# [['3730457171_e66dde8c91.jpg' '0.2492714524269104']
#  ['759015118_4bd3617e60.jpg' '0.22485288977622986']
#  ['2603334363_cfa32c4482.jpg' '0.21882811188697815']]
# ==== Epoch:  510  loss:  7.647  | running avg loss:  7.784
# ==== Epoch:  520  loss:  5.865  | running avg loss:  7.757
# ==== Epoch:  530  loss:  5.57  | running avg loss:  7.733
# ==== Epoch:  540  loss:  6.438  | running avg loss:  7.711
# ==== Epoch:  550  loss:  6.235  | running avg loss:  7.686
# ==== Epoch:  560  loss:  7.55  | running avg loss:  7.664
# ==== Epoch:  570  loss:  6.5  | running avg loss:  7.643
# ==== Epoch:  580  loss:  5.946  | running avg loss:  7.622
# ==== Epoch:  590  loss:  6.451  | running avg loss:  7.591
# ==== Epoch:  600  loss:  5.397  | running avg loss:  7.571
# [['3730457171_e66dde8c91.jpg' '0.2545538544654846']
#  ['2603334363_cfa32c4482.jpg' '0.22182589769363403']
#  ['759015118_4bd3617e60.jpg' '0.2206842005252838']]
# ==== Epoch:  610  loss:  6.178  | running avg loss:  7.545
# ==== Epoch:  620  loss:  6.551  | running avg loss:  7.534
# ==== Epoch:  630  loss:  6.321  | running avg loss:  7.513
# ==== Epoch:  640  loss:  6.256  | running avg loss:  7.494
# ==== Epoch:  650  loss:  6.605  | running avg loss:  7.473
# ==== Epoch:  660  loss:  6.317  | running avg loss:  7.451
# ==== Epoch:  670  loss:  6.283  | running avg loss:  7.431
# ==== Epoch:  680  loss:  6.019  | running avg loss:  7.41
# ==== Epoch:  690  loss:  6.179  | running avg loss:  7.388
# ==== Epoch:  700  loss:  6.092  | running avg loss:  7.371
# [['3730457171_e66dde8c91.jpg' '0.24194158613681793']
#  ['2603334363_cfa32c4482.jpg' '0.2084766924381256']
#  ['759015118_4bd3617e60.jpg' '0.20738337934017181']]
# ==== Epoch:  710  loss:  6.529  | running avg loss:  7.352
# ==== Epoch:  720  loss:  5.696  | running avg loss:  7.336
# ==== Epoch:  730  loss:  5.846  | running avg loss:  7.321
# ==== Epoch:  740  loss:  5.865  | running avg loss:  7.3
# ==== Epoch:  750  loss:  5.974  | running avg loss:  7.284
# ==== Epoch:  760  loss:  5.117  | running avg loss:  7.266
# ==== Epoch:  770  loss:  4.914  | running avg loss:  7.251
# ==== Epoch:  780  loss:  6.087  | running avg loss:  7.234
# ==== Epoch:  790  loss:  5.183  | running avg loss:  7.219
# ==== Epoch:  800  loss:  5.131  | running avg loss:  7.207
# [['3730457171_e66dde8c91.jpg' '0.24192257225513458']
#  ['2863349041_5eba6e3e21.jpg' '0.20880304276943207']
#  ['2603334363_cfa32c4482.jpg' '0.20513944327831268']]
# ==== Epoch:  810  loss:  5.405  | running avg loss:  7.186
# ==== Epoch:  820  loss:  5.329  | running avg loss:  7.167
# ==== Epoch:  830  loss:  4.963  | running avg loss:  7.151
# ==== Epoch:  840  loss:  5.421  | running avg loss:  7.131
# ==== Epoch:  850  loss:  5.447  | running avg loss:  7.114
# ==== Epoch:  860  loss:  5.193  | running avg loss:  7.094
# ==== Epoch:  870  loss:  6.706  | running avg loss:  7.084
# ==== Epoch:  880  loss:  5.854  | running avg loss:  7.07
# ==== Epoch:  890  loss:  4.971  | running avg loss:  7.055
# ==== Epoch:  900  loss:  5.558  | running avg loss:  7.038
# [['3730457171_e66dde8c91.jpg' '0.23447208106517792']
#  ['2863349041_5eba6e3e21.jpg' '0.20677506923675537']
#  ['2603334363_cfa32c4482.jpg' '0.19711555540561676']]
# ==== Epoch:  910  loss:  6.083  | running avg loss:  7.021
# ==== Epoch:  920  loss:  4.908  | running avg loss:  7.004
# ==== Epoch:  930  loss:  6.462  | running avg loss:  6.994
# ==== Epoch:  940  loss:  5.551  | running avg loss:  6.983
# ==== Epoch:  950  loss:  5.69  | running avg loss:  6.974
# ==== Epoch:  960  loss:  5.866  | running avg loss:  6.962
# ==== Epoch:  970  loss:  5.987  | running avg loss:  6.948
# ==== Epoch:  980  loss:  5.836  | running avg loss:  6.934
# ==== Epoch:  990  loss:  5.528  | running avg loss:  6.919
# ==== Epoch:  1000  loss:  4.961  | running avg loss:  6.906
# [['3730457171_e66dde8c91.jpg' '0.22632330656051636']
#  ['2863349041_5eba6e3e21.jpg' '0.20300573110580444']
#  ['2603334363_cfa32c4482.jpg' '0.18701483309268951']]
# ==== Epoch:  1010  loss:  5.752  | running avg loss:  6.894
# ==== Epoch:  1020  loss:  6.228  | running avg loss:  6.882
# ==== Epoch:  1030  loss:  5.003  | running avg loss:  6.869
# ==== Epoch:  1040  loss:  5.341  | running avg loss:  6.856
# ==== Epoch:  1050  loss:  5.131  | running avg loss:  6.844
# ==== Epoch:  1060  loss:  5.816  | running avg loss:  6.834
# ==== Epoch:  1070  loss:  4.508  | running avg loss:  6.822
# ==== Epoch:  1080  loss:  5.06  | running avg loss:  6.809
# ==== Epoch:  1090  loss:  4.309  | running avg loss:  6.8
# ==== Epoch:  1100  loss:  5.359  | running avg loss:  6.791
# [['3730457171_e66dde8c91.jpg' '0.21744798123836517']
#  ['2863349041_5eba6e3e21.jpg' '0.20015272498130798']
#  ['3726076549_0efb38854b.jpg' '0.18114009499549866']]
# ==== Epoch:  1110  loss:  5.192  | running avg loss:  6.781
# ==== Epoch:  1120  loss:  6.018  | running avg loss:  6.77
# ==== Epoch:  1130  loss:  6.125  | running avg loss:  6.76
# ==== Epoch:  1140  loss:  7.151  | running avg loss:  6.748
# ==== Epoch:  1150  loss:  5.248  | running avg loss:  6.739
# ==== Epoch:  1160  loss:  5.111  | running avg loss:  6.731
# ==== Epoch:  1170  loss:  4.505  | running avg loss:  6.719
# ==== Epoch:  1180  loss:  6.425  | running avg loss:  6.711
# ==== Epoch:  1190  loss:  5.027  | running avg loss:  6.7
# ==== Epoch:  1200  loss:  4.907  | running avg loss:  6.691
# [['3730457171_e66dde8c91.jpg' '0.21185363829135895']
#  ['2863349041_5eba6e3e21.jpg' '0.19400736689567566']
#  ['3726076549_0efb38854b.jpg' '0.1785246878862381']]
# ==== Epoch:  1210  loss:  5.05  | running avg loss:  6.683
# ==== Epoch:  1220  loss:  4.207  | running avg loss:  6.671
# ==== Epoch:  1230  loss:  5.851  | running avg loss:  6.661
# ==== Epoch:  1240  loss:  4.99  | running avg loss:  6.649
# ==== Epoch:  1250  loss:  6.301  | running avg loss:  6.642
# ==== Epoch:  1260  loss:  5.763  | running avg loss:  6.632
# ==== Epoch:  1270  loss:  5.255  | running avg loss:  6.624
# ==== Epoch:  1280  loss:  6.528  | running avg loss:  6.617
# ==== Epoch:  1290  loss:  6.356  | running avg loss:  6.607
# ==== Epoch:  1300  loss:  5.019  | running avg loss:  6.599
# [['3730457171_e66dde8c91.jpg' '0.2023039311170578']
#  ['2863349041_5eba6e3e21.jpg' '0.1901177167892456']
#  ['3726076549_0efb38854b.jpg' '0.18553954362869263']]
# ==== Epoch:  1310  loss:  4.609  | running avg loss:  6.588
# ==== Epoch:  1320  loss:  5.082  | running avg loss:  6.577
# ==== Epoch:  1330  loss:  4.854  | running avg loss:  6.569
# ==== Epoch:  1340  loss:  5.021  | running avg loss:  6.561
# ==== Epoch:  1350  loss:  6.092  | running avg loss:  6.551
# ==== Epoch:  1360  loss:  6.168  | running avg loss:  6.541
# ==== Epoch:  1370  loss:  5.229  | running avg loss:  6.533
# ==== Epoch:  1380  loss:  5.411  | running avg loss:  6.527
# ==== Epoch:  1390  loss:  5.109  | running avg loss:  6.519
# ==== Epoch:  1400  loss:  4.78  | running avg loss:  6.511
# [['3730457171_e66dde8c91.jpg' '0.20176704227924347']
#  ['2863349041_5eba6e3e21.jpg' '0.1910979300737381']
#  ['3726076549_0efb38854b.jpg' '0.18492604792118073']]
# ==== Epoch:  1410  loss:  5.542  | running avg loss:  6.503
# ==== Epoch:  1420  loss:  6.288  | running avg loss:  6.498
# ==== Epoch:  1430  loss:  5.843  | running avg loss:  6.488
# ==== Epoch:  1440  loss:  4.44  | running avg loss:  6.48
# ==== Epoch:  1450  loss:  5.184  | running avg loss:  6.472
# ==== Epoch:  1460  loss:  4.905  | running avg loss:  6.463
# ==== Epoch:  1470  loss:  5.563  | running avg loss:  6.455
# ==== Epoch:  1480  loss:  5.57  | running avg loss:  6.446
# ==== Epoch:  1490  loss:  5.201  | running avg loss:  6.437
# ==== Epoch:  1500  loss:  5.301  | running avg loss:  6.43
# [['3730457171_e66dde8c91.jpg' '0.2052430510520935']
#  ['2863349041_5eba6e3e21.jpg' '0.19396749138832092']
#  ['3726076549_0efb38854b.jpg' '0.18376843631267548']]
# ==== Epoch:  1510  loss:  5.598  | running avg loss:  6.423
# ==== Epoch:  1520  loss:  5.048  | running avg loss:  6.417
# ==== Epoch:  1530  loss:  4.215  | running avg loss:  6.407
# ==== Epoch:  1540  loss:  6.035  | running avg loss:  6.4
# ==== Epoch:  1550  loss:  6.535  | running avg loss:  6.394
# ==== Epoch:  1560  loss:  4.05  | running avg loss:  6.385
# ==== Epoch:  1570  loss:  5.13  | running avg loss:  6.379
# ==== Epoch:  1580  loss:  5.018  | running avg loss:  6.371
# ==== Epoch:  1590  loss:  5.731  | running avg loss:  6.365
# ==== Epoch:  1600  loss:  5.495  | running avg loss:  6.357
# [['3730457171_e66dde8c91.jpg' '0.19269654154777527']
#  ['2863349041_5eba6e3e21.jpg' '0.18260355293750763']
#  ['3726076549_0efb38854b.jpg' '0.18056149780750275']]
# ==== Epoch:  1610  loss:  4.826  | running avg loss:  6.348
# ==== Epoch:  1620  loss:  4.643  | running avg loss:  6.342
# ==== Epoch:  1630  loss:  4.856  | running avg loss:  6.334
# ==== Epoch:  1640  loss:  6.123  | running avg loss:  6.327
# ==== Epoch:  1650  loss:  4.871  | running avg loss:  6.319
# ==== Epoch:  1660  loss:  6.366  | running avg loss:  6.315
# ==== Epoch:  1670  loss:  4.558  | running avg loss:  6.308
# ==== Epoch:  1680  loss:  5.103  | running avg loss:  6.302
# ==== Epoch:  1690  loss:  4.241  | running avg loss:  6.296
# ==== Epoch:  1700  loss:  5.083  | running avg loss:  6.289
# [['3730457171_e66dde8c91.jpg' '0.19104652106761932']
#  ['2863349041_5eba6e3e21.jpg' '0.1819358766078949']
#  ['3726076549_0efb38854b.jpg' '0.17759254574775696']]
# ==== Epoch:  1710  loss:  4.023  | running avg loss:  6.281
# ==== Epoch:  1720  loss:  4.271  | running avg loss:  6.274
# ==== Epoch:  1730  loss:  4.999  | running avg loss:  6.267
# ==== Epoch:  1740  loss:  5.129  | running avg loss:  6.26
# ==== Epoch:  1750  loss:  5.144  | running avg loss:  6.25
# ==== Epoch:  1760  loss:  5.218  | running avg loss:  6.246
# ==== Epoch:  1770  loss:  4.168  | running avg loss:  6.242
# ==== Epoch:  1780  loss:  5.322  | running avg loss:  6.234
# ==== Epoch:  1790  loss:  6.141  | running avg loss:  6.227
# ==== Epoch:  1800  loss:  4.833  | running avg loss:  6.22
# [['3730457171_e66dde8c91.jpg' '0.1896720677614212']
#  ['2863349041_5eba6e3e21.jpg' '0.18207193911075592']
#  ['3726076549_0efb38854b.jpg' '0.1775064319372177']]
# ==== Epoch:  1810  loss:  4.219  | running avg loss:  6.213
# ==== Epoch:  1820  loss:  4.858  | running avg loss:  6.208
# ==== Epoch:  1830  loss:  3.824  | running avg loss:  6.203
# ==== Epoch:  1840  loss:  5.581  | running avg loss:  6.198
# ==== Epoch:  1850  loss:  4.595  | running avg loss:  6.193
# ==== Epoch:  1860  loss:  5.995  | running avg loss:  6.189
# ==== Epoch:  1870  loss:  5.168  | running avg loss:  6.182
# ==== Epoch:  1880  loss:  5.096  | running avg loss:  6.175
# ==== Epoch:  1890  loss:  4.403  | running avg loss:  6.169
# ==== Epoch:  1900  loss:  4.966  | running avg loss:  6.163
# [['3730457171_e66dde8c91.jpg' '0.18403911590576172']
#  ['2863349041_5eba6e3e21.jpg' '0.1753389835357666']
#  ['3726076549_0efb38854b.jpg' '0.1721808761358261']]
# ==== Epoch:  1910  loss:  4.059  | running avg loss:  6.157
# ==== Epoch:  1920  loss:  5.787  | running avg loss:  6.151
# ==== Epoch:  1930  loss:  5.904  | running avg loss:  6.146
# ==== Epoch:  1940  loss:  4.726  | running avg loss:  6.139
# ==== Epoch:  1950  loss:  4.761  | running avg loss:  6.133
# ==== Epoch:  1960  loss:  4.636  | running avg loss:  6.127
# ==== Epoch:  1970  loss:  5.288  | running avg loss:  6.122
# ==== Epoch:  1980  loss:  5.645  | running avg loss:  6.116
# ==== Epoch:  1990  loss:  4.703  | running avg loss:  6.111

# %%
plot_image('Flicker8k_Dataset/2863349041_5eba6e3e21.jpg')
# Out:
# FigureCanvasNbAgg()

# %%
plot_image('Flicker8k_Dataset/3726076549_0efb38854b.jpg')
# Out:
# FigureCanvasNbAgg()

# %%
plot_image('Flicker8k_Dataset/3730457171_e66dde8c91.jpg')
# Out:
# FigureCanvasNbAgg()
